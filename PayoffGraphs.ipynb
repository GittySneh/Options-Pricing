# %% [markdown]
# # **INTRODUCTION TO OPTIONS**

# %% [markdown]
# [Basics of options](https://corporatefinanceinstitute.com/resources/derivatives/options-calls-and-puts/)

# %%
# %pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\sneh\anaconda3\lib\site-packages (0.2.40)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\sneh\anaconda3\lib\site-packages (from yfinance) (1.23.5)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\sneh\anaconda3\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\sneh\anaconda3\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\sneh\anaconda3\lib\site-packages (from yfinance) (3.17.5)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\sneh\anaconda3\lib\site-packages (from yfinance) (2.5.2)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\sneh\anaconda3\lib\site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: pytz>=2022.5 in c:\users\sneh\anaconda3\lib\site-packages (from yfinance) (2022.7)
# Requirement already satisfied: requests>=2.31 in c:\users\sneh\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: html5lib>=1.1 in c:\users\sneh\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\sneh\anaconda3\lib\site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\sneh\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sneh\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\sneh\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\sneh\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\sneh\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sneh\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2022.12.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sneh\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sneh\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sneh\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **IMPORTING THE LIBRARIES**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from datetime import date


import warnings
warnings.filterwarnings("ignore")

# to fetch data
import yfinance as yf

# %% [markdown]
# **IMPORTING DATA FOR OPTIONS**

# %%
symbol = '^SPX'  #the ticker of the stock whose data is to be taken out
dfo = yf.Ticker(symbol)

# %%
dfo.options  #to get the date of different expiration time
# Out:
# ('2024-07-01',
#  '2024-07-02',
#  '2024-07-03',
#  '2024-07-05',
#  '2024-07-08',
#  '2024-07-09',
#  '2024-07-10',
#  '2024-07-11',
#  '2024-07-12',
#  '2024-07-15',
#  '2024-07-16',
#  '2024-07-17',
#  '2024-07-18',
#  '2024-07-19',
#  '2024-07-22',
#  '2024-07-23',
#  '2024-07-24',
#  '2024-07-25',
#  '2024-07-26',
#  '2024-07-29',
#  '2024-07-30',
#  '2024-07-31',
#  '2024-08-01',
#  '2024-08-02',
#  '2024-08-09',
#  '2024-08-16',
#  '2024-08-30',
#  '2024-09-20',
#  '2024-09-30',
#  '2024-10-18',
#  '2024-10-31',
#  '2024-11-15',
#  '2024-11-29',
#  '2024-12-20',
#  '2024-12-31',
#  '2025-01-17',
#  '2025-02-21',
#  '2025-03-21',
#  '2025-03-31',
#  '2025-04-17',
#  '2025-05-16',
#  '2025-06-20',
#  '2025-07-18',
#  '2025-09-19',
#  '2025-12-19',
#  '2026-03-20',
#  '2026-06-18',
#  '2026-12-18',
#  '2027-12-17',
#  '2028-12-15',
#  '2029-12-21')

# %%
dfo_exp = dfo.option_chain(dfo.options[1])  #to get data of next recent expiry date

# %%
dfo_exp.calls #Data for call options
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0    SPXW240702C04000000 2024-06-13 15:43:08+00:00  4000.0    1430.33  1468.5
# 1    SPXW240702C04550000 2024-06-10 16:20:55+00:00  4550.0     820.95   918.7
# 2    SPXW240702C04700000 2024-05-23 17:17:52+00:00  4700.0     630.40   767.1
# 3    SPXW240702C04800000 2024-06-27 14:27:49+00:00  4800.0     691.77   669.1
# 4    SPXW240702C04850000 2024-06-28 17:09:15+00:00  4850.0     640.03   619.7
# ..                   ...                       ...     ...        ...     ...
# 112  SPXW240702C05800000 2024-06-24 18:55:39+00:00  5800.0       0.10     0.0
# 113  SPXW240702C05900000 2024-06-26 01:02:28+00:00  5900.0       0.07     0.0
# 114  SPXW240702C06000000 2024-06-21 18:05:19+00:00  6000.0       0.10     0.0
# 115  SPXW240702C06100000 2024-06-21 20:00:07+00:00  6100.0       0.05     0.0
# 116  SPXW240702C06600000 2024-06-21 18:46:05+00:00  6600.0       0.05     0.0
#
#         ask     change  percentChange  volume  openInterest  \
# 0    1477.1    0.00000       0.000000     1.0             1
# 1     927.3    0.00000       0.000000     1.0             1
# 2     784.4    0.00000       0.000000     NaN             0
# 3     677.3    0.00000       0.000000     1.0             2
# 4     626.6  156.93002      32.483963    20.0             0
# ..      ...        ...            ...     ...           ...
# 112     0.1    0.00000       0.000000     2.0             7
# 113     0.1    0.00000       0.000000     1.0            26
# 114     0.1    0.00000       0.000000     1.0            20
# 115     0.1    0.00000       0.000000     3.0             3
# 116     0.1    0.00000       0.000000     1.0             1
#
#      impliedVolatility  inTheMoney contractSize currency
# 0             1.672426        True      REGULAR      USD
# 1             1.077153        True      REGULAR      USD
# 2             0.961365        True      REGULAR      USD
# 3             0.818514        True      REGULAR      USD
# 4             0.765627        True      REGULAR      USD
# ..                 ...         ...          ...      ...
# 112           0.207527       False      REGULAR      USD
# 113           0.259773       False      REGULAR      USD
# 114           0.310065       False      REGULAR      USD
# 115           0.359381       False      REGULAR      USD
# 116           0.554692       False      REGULAR      USD
#
# [117 rows x 14 columns]

# %%
dfo_exp.puts #Data for put options
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0    SPXW240702P02600000 2024-05-30 17:26:13+00:00  2600.0       0.12    0.0
# 1    SPXW240702P02800000 2024-06-11 14:36:33+00:00  2800.0       0.05    0.0
# 2    SPXW240702P03400000 2024-06-14 19:15:54+00:00  3400.0       0.10    0.0
# 3    SPXW240702P03600000 2024-06-24 19:35:38+00:00  3600.0       0.05    0.0
# 4    SPXW240702P03800000 2024-06-25 13:38:36+00:00  3800.0       0.05    0.0
# ..                   ...                       ...     ...        ...    ...
# 122  SPXW240702P05535000 2024-06-28 16:57:45+00:00  5535.0      54.10   59.4
# 123  SPXW240702P05540000 2024-06-28 18:13:07+00:00  5540.0      55.90   64.1
# 124  SPXW240702P05550000 2024-06-28 17:04:24+00:00  5550.0      65.33   73.7
# 125  SPXW240702P05555000 2024-06-28 17:30:03+00:00  5555.0      71.70   78.5
# 126  SPXW240702P05900000 2024-06-12 19:38:12+00:00  5900.0     464.11  422.3
#
#        ask     change  percentChange  volume  openInterest  impliedVolatility  \
# 0      0.1   0.000000       0.000000     2.0             2           2.035161
# 1      0.1   0.000000       0.000000     NaN             1           1.839845
# 2      0.1   0.000000       0.000000    69.0           128           1.328128
# 3      0.1   0.000000       0.000000   296.0           332           1.175785
# 4      0.1   0.000000       0.000000   100.0           314           1.031255
# ..     ...        ...            ...     ...           ...                ...
# 122   66.2   4.029999       8.048730   227.0             5           0.000010
# 123   70.9 -12.839996     -18.679077   436.0             5           0.000010
# 124   80.5   3.370003       5.438998   206.0           363           0.000010
# 125   85.4   9.599998      15.458936   201.0             3           0.000010
# 126  430.9   0.000000       0.000000     NaN             1           0.000010
#
#      inTheMoney contractSize currency
# 0         False      REGULAR      USD
# 1         False      REGULAR      USD
# 2         False      REGULAR      USD
# 3         False      REGULAR      USD
# 4         False      REGULAR      USD
# ..          ...          ...      ...
# 122        True      REGULAR      USD
# 123        True      REGULAR      USD
# 124        True      REGULAR      USD
# 125        True      REGULAR      USD
# 126        True      REGULAR      USD
#
# [127 rows x 14 columns]

# %%
#run this tab to make you aware of the latest price

symbol = '^SPX'
end = date.today()
start = end.replace(year = 2022)


# Read data
df = yf.download(symbol,start,end)

df.tail()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2024-06-24  5459.580078  5490.660156  5447.589844  5447.870117  5447.870117
# 2024-06-25  5460.729980  5472.879883  5446.560059  5469.299805  5469.299805
# 2024-06-26  5460.709961  5483.140137  5451.870117  5477.899902  5477.899902
# 2024-06-27  5473.589844  5490.810059  5467.540039  5482.870117  5482.870117
# 2024-06-28  5488.479980  5523.640137  5451.120117  5460.479980  5460.479980
#
#                 Volume
# Date
# 2024-06-24  3696750000
# 2024-06-25  3591960000
# 2024-06-26  3563920000
# 2024-06-27  3589530000
# 2024-06-28  7199220000

# %% [markdown]
# # **PAYOFF FROM CALL AND PUT OPTIONS**

# %% [markdown]
# # **Call option**
# payoff=max(-C, S - X - C)

# %% [markdown]
# # **Put option**
# payoff=max(-P, X - S - P)
#
# P and C are premiums of calls and puts
#
# S is the stock price
#
# X is the strike price

# %%
def payoff(option_type, premium, S, X):
  Payoff = 0
  if option_type == 'C':
    Payoff = max(-premium , S - X - premium )
  elif option_type =='P':
    Payoff = max (-premium , X-S-premium )
  else:
   print("INVALID TYPE")
  return Payoff

# %% [markdown]
# Checking the output of payoff function

# %%
payoff('C', 10, 120,100)
# Out:
# 10

# %%
payoff('Z', 10, 120, 100)
# Out:
# INVALID TYPE
# 0

# %%
payoff('P', 10, 120, 100)
# Out:
# -10

# %% [markdown]
# # **PAYOFF GRAPHS**

# %% [markdown]
# **CALL OPTION**

# %%
X = dfo_exp.calls['strike'][0]
premium = dfo_exp.calls['lastPrice'][0]

# %%
StockPrice = np.arange(0, 6000)
Payoff = [payoff('C', premium, i, X) for i in StockPrice]

# %%
#PLOTTING THE PAYOFF GRAPH FOR CALL OPTION
plt.plot(StockPrice, Payoff, label = 'payoff line')
plt.xlabel('Stock Price')
plt.ylabel('payoff')
plt.title('Call option Payoff at Expiry')
plt.grid(True)

#breakeven point is when payoff is 0 or S=X+C
plt.plot(X+premium, 0, 'ro', label = 'breakeven point')
plt.legend()

# %% [markdown]
# **PUT OPTION**

# %%
X = dfo_exp.puts['strike'][len(dfo_exp.puts)-1]
premium = dfo_exp.puts['lastPrice'][len(dfo_exp.puts)-1]

# %%
StockPrice = np.arange(0, 6000)
Payoff = [payoff('P', premium, i, X) for i in StockPrice]

# %%
#PLOTTING THE PAYOFF GRAPH FOR PUT OPTION

plt.plot(StockPrice, Payoff, label = 'payoff line')
plt.xlabel('Stock Price')
plt.ylabel('payoff')
plt.title('Put option Payoff at Expiry')
plt.grid(True)

#breakeven point is when payoff is 0
plt.plot(X-premium, 0, 'ro', label = 'breakeven point')
plt.legend()
